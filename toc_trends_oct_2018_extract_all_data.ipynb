# %%
# %matplotlib inline
import nivapy3 as nivapy
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sn

plt.style.use('ggplot')

# %%
# Connect to NIVABASE
eng = nivapy.da.connect()
# Out:
# Connection successful.

# %% [markdown]
# # ICPW: extract all time series data for TOC trends 1990 to 2016
#
# ## 1. Select project

# %%
# Query projects
prj_grid = nivapy.da.select_resa_projects(eng)
prj_grid
# Out:
# 583 projects in the RESA database.
# QgridWidget(grid_options={'fullWidthRows': True, 'syncColumnCellResize': True, 'forceFitColumns': True, 'defau…

# %%
# Get project
prj_df = prj_grid.get_selected_df()
prj_df
# Out:
#      project_id project_number         project_name contact_person  \
# 580        4390           None  ICPW_TOCTRENDS_2018           None
#
#     project_description
# 580                None

# %% [markdown]
# ## 2. Select stations

# %%
# Get project stations
stn_df = nivapy.da.select_resa_project_stations(prj_df, eng)
print(len(stn_df), 'stations in project.')
stn_df.head()
# Out:
# 432 stations in project.
#    station_id station_code                                station_name  \
# 0       38323   Tr18_BA-01                            Batizovské pleso
# 1       38085    Tr18_CA01     Ontario, Algoma Region, Batchawana Lake
# 2       38086    Tr18_CA02        Ontario, Algoma Region, Wishart Lake
# 3       38087    Tr18_CA03  Ontario, Algoma Region, Little Turkey Lake
# 4       38088    Tr18_CA04         Ontario, Algoma Region, Turkey Lake
#
#    latitude  longitude  altitude
# 0  49.15203   20.12988      1884
# 1  47.06000  -84.39300       497
# 2  47.04100  -84.40200       388
# 3  47.04100  -84.40600       375
# 4  47.05000  -84.40800       372

# %%
# Map of stations
nivapy.spatial.quickmap(stn_df, 
                        popup='station_code',
                        cluster=True)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## 3. Get parameters

# %%
# Get available pars
st_dt = '1990-01-01'
end_dt = '2016-12-31'
par_grid = nivapy.da.select_resa_station_parameters(stn_df,
                                                    st_dt,
                                                    end_dt,
                                                    eng)
par_grid
# Out:
# 34 parameters available for the selected stations and dates.
# QgridWidget(grid_options={'fullWidthRows': True, 'syncColumnCellResize': True, 'forceFitColumns': True, 'defau…

# %%
# Select all pars
par_df = par_grid.get_selected_df()
print(len(par_df), 'parameters selected.')
par_df.head()
# Out:
# 33 parameters selected.
#    parameter_id parameter_name  unit
# 1            50             Al  µg/l
# 2           223             As  µg/l
# 3           959         COLOUR  None
# 4            11             Ca  mg/l
# 5            15             Cd  µg/l

# %% [markdown]
# ## 4. Get water chemsitry

# %%
# Get chem
wc_df, dup_df = nivapy.da.select_resa_water_chemistry(stn_df,
                                                      par_df,
                                                      st_dt,
                                                      end_dt,
                                                      eng,
                                                      drop_dups=True,
                                                      lod_flags=False)
wc_df.head()
# Out:
#    station_id station_code                             station_name  \
#
# 0       38085    Tr18_CA01  Ontario, Algoma Region, Batchawana Lake
# 1       38085    Tr18_CA01  Ontario, Algoma Region, Batchawana Lake
# 2       38085    Tr18_CA01  Ontario, Algoma Region, Batchawana Lake
# 3       38085    Tr18_CA01  Ontario, Algoma Region, Batchawana Lake
# 4       38085    Tr18_CA01  Ontario, Algoma Region, Batchawana Lake
#
#   sample_date  depth1  depth2  ALK-E_µEq/l  Al_µg/l  As_µg/l  COLOUR_  ...   \
#                                                                        ...
# 0  1990-01-03       0       0         50.5     86.6      NaN      NaN  ...
# 1  1990-01-09       0       0         50.0     84.0      NaN      NaN  ...
# 2  1990-01-15       0       0         50.9     81.4      NaN      NaN  ...
# 3  1990-01-24       0       0         56.6     76.8      NaN      NaN  ...
# 4  1990-01-31       0       0         59.9    124.2      NaN      NaN  ...
#
#    Pb_µg/l  Qs_m3/s  SO4_mg/l  SiO2_mg SiO2/l  TOC_mg C/l  TOTN_µg/l N  \
#
# 0      NaN      NaN      5.63            2.01        4.17        352.0
# 1      NaN      NaN      5.53            2.01        3.94        598.0
# 2      NaN      NaN      5.47            2.06        3.69        530.0
# 3      NaN      NaN      5.34            2.05        3.71        493.0
# 4      NaN      NaN      5.64            2.10        3.85        815.0
#
#    TOTP_µg/l P  Temp_oC  Zn_µg/l   pH_
#
# 0          6.1      NaN      8.2  6.95
# 1          5.7      NaN      8.2  6.05
# 2          5.8      NaN      7.3  6.07
# 3          4.7      NaN      8.6  5.93
# 4          8.9      NaN      8.9  5.97
#
# [5 rows x 39 columns]

# %%
# Save output
out_csv = r'../../update_autumn_2018/results/all_chem_1990-2016.csv'
wc_df.to_csv(out_csv, index=False, encoding='utf-8')
