# %%
# %matplotlib inline
import nivapy3 as nivapy
import numpy as np
import pandas as pd
import os
import seaborn as sn
import matplotlib.pyplot as plt
import toc_trends_analysis as resa2_trends
import warnings

warnings.filterwarnings("ignore", message="Mean of empty slice")
plt.style.use('ggplot')

# %%
# Connect to NIVABASE
eng = nivapy.da.connect()
# Out:
# Connection successful.

# %% [markdown]
# # TOC trends - October 2018 (Part 2: Chemistry trend analysis)
#
# The previous notebook created a new dataset for the trends analysis spanning ther period from 1990 to 2016. This notebook takes the new dataset and applies the same trends workflow as previously (from 2016 - see [here](https://nbviewer.jupyter.org/github/JamesSample/icpw/blob/master/toc_trends_oct_2016_part2.ipynb) for details).

# %%
# User input
# Specify projects of interest
proj_list = ['ICPW_TOCTRENDS_2018',]

# Specify results folder
res_fold = (r'../../update_autumn_2018/results')

# %% [markdown]
# ## 1. 1990 to 2012
#
# The code below is just for testing purposes: it runs the analysis from 1990 to 2012, which should be directly comparable to the data used during the 2016 analysis. The output generated below can therefore be compared to
#
#     C:\Data\James_Work\Staff\Heleen_d_W\ICP_Waters\TOC_Trends_Analysis_2015\Results\res_1990-2012.csv
#
# and any differences *should* be due to changes in the data (which are hopefully due to finding and fixing errors).

# %%
# Specify period of interest
st_yr, end_yr = 1990, 2012

# Build output paths
plot_fold = os.path.join(res_fold, 'trends_plots_%s-%s' % (st_yr, end_yr))
res_csv = os.path.join(res_fold, 'res_%s-%s.csv' % (st_yr, end_yr))
dup_csv = os.path.join(res_fold, 'dup_%s-%s.csv' % (st_yr, end_yr))
nd_csv = os.path.join(res_fold, 'nd_%s-%s.csv' % (st_yr, end_yr))

# Run analysis 
res_df, dup_df, nd_df = resa2_trends.run_trend_analysis(proj_list, 
                                                        eng,
                                                        st_yr=st_yr, 
                                                        end_yr=end_yr,
                                                        plot=False, 
                                                        fold=None)

# Delete mk_std_dev col as not relevant here
del res_df['mk_std_dev']

# Write output
res_df.to_csv(res_csv, index=False)
dup_df.to_csv(dup_csv, index=False)
if nd_df:
    nd_df.to_csv(nd_csv, index=False)
# Out:
# Extracting data from RESA2...
#     Done.
#
# Converting units and applying sea-salt correction...
#     Done.
#
# Calculating statistics...
#     Data series for Al at site 38089 has fewer than 10 non-null values. Significance estimates may be unreliable.
#     Data series for Al at site 38090 has fewer than 10 non-null values. Significance estimates may be unreliable.
#     Data series for Al at site 38091 has fewer than 10 non-null values. Significance estimates may be unreliable.
#     Data series for Al at site 38093 has fewer than 10 non-null values. Significance estimates may be unreliable.
#     Data series for TOC at site 38101 has fewer than 10 non-null values. Significance estimates may be unreliable.
#     Data series for EH at site 38101 has fewer than 10 non-null values. Significance estimates may be unreliable.
#     Data series for ESO4 at site 38101 has fewer than 10 non-null values. Significance estimates may be unreliable.
#     Data series for ECl at site 38101 has fewer than 10 non-null values. Significance estimates may be unreliable.
#     Data series for ENO3 at site 38101 has fewer than 10 non-null values. Significance estimates may be unreliable.
#     Data series for ESO4X at site 38101 has fewer than 10 non-null values. Significance estimates may be unreliable.
#     Data series for ESO4_ECl at site 38101 has fewer than 10 non-null values. Significance estimates may be unreliable.
#     Data series for ECa_EMg at site 38101 has fewer than 10 non-null values. Significance estimates may be unreliable.
#     Data series for ECaX_EMgX at site 38101 has fewer than 10 non-null values. Significance estimates may be unreliable.
#     Data series for ANC at site 38101 has fewer than 10 non-null values. Significance estimates may be unreliable.
#     Data series for TOC at site 38208 has fewer than 10 non-null values. Significance estimates may be unreliable.
#     Data series for Al at site 38210 has fewer than 10 non-null values. Significance estimates may be unreliable.
#     Data series for Al at site 38211 has fewer than 10 non-null values. Significance estimates may be unreliable.
#     Data series for Al at site 38221 has fewer than 10 non-null values. Significance estimates may be unreliable.
#     Data series for Al at site 38234 has fewer than 10 non-null values. Significance estimates may be unreliable.
#     Data series for Al at site 38236 has fewer than 10 non-null values. Significance estimates may be unreliable.
#     Data series for Al at site 38237 has fewer than 10 non-null values. Significance estimates may be unreliable.
#     Data series for Al at site 38238 has fewer than 10 non-null values. Significance estimates may be unreliable.
#     Data series for Al at site 38239 has fewer than 10 non-null values. Significance estimates may be unreliable.
#     Data series for Al at site 38250 has fewer than 10 non-null values. Significance estimates may be unreliable.
#     Data series for Al at site 38258 has fewer than 10 non-null values. Significance estimates may be unreliable.
#     Data series for Al at site 38272 has fewer than 10 non-null values. Significance estimates may be unreliable.
#     Data series for Al at site 38280 has fewer than 10 non-null values. Significance estimates may be unreliable.
#     Data series for Al at site 38291 has fewer than 10 non-null values. Significance estimates may be unreliable.
#     Data series for Al at site 38301 has fewer than 10 non-null values. Significance estimates may be unreliable.
#     Data series for Al at site 38307 has fewer than 10 non-null values. Significance estimates may be unreliable.
#     Data series for EH at site 38494 has fewer than 10 non-null values. Significance estimates may be unreliable.
#     Data series for EH at site 38495 has fewer than 10 non-null values. Significance estimates may be unreliable.
#     Data series for EH at site 38496 has fewer than 10 non-null values. Significance estimates may be unreliable.
#     Data series for EH at site 38497 has fewer than 10 non-null values. Significance estimates may be unreliable.
#     Data series for EH at site 38498 has fewer than 10 non-null values. Significance estimates may be unreliable.
#     Data series for EH at site 38499 has fewer than 10 non-null values. Significance estimates may be unreliable.
#     Data series for EH at site 38500 has fewer than 10 non-null values. Significance estimates may be unreliable.
#     Data series for EH at site 38501 has fewer than 10 non-null values. Significance estimates may be unreliable.
#     Done.
#
# Finished.

# %% [markdown]
# ## 2. 1990 to 2016

# %%
# Specify period of interest
st_yr, end_yr = 1990, 2016

# Build output paths
plot_fold = os.path.join(res_fold, 'trends_plots_%s-%s' % (st_yr, end_yr))
res_csv = os.path.join(res_fold, 'res_%s-%s.csv' % (st_yr, end_yr))
dup_csv = os.path.join(res_fold, 'dup_%s-%s.csv' % (st_yr, end_yr))
nd_csv = os.path.join(res_fold, 'nd_%s-%s.csv' % (st_yr, end_yr))

# Run analysis 
res_df, dup_df, nd_df = resa2_trends.run_trend_analysis(proj_list, 
                                                        eng,
                                                        st_yr=st_yr, 
                                                        end_yr=end_yr,
                                                        plot=False, 
                                                        fold=None)

# Delete mk_std_dev col as not relevant here
del res_df['mk_std_dev']

# Write output
res_df.to_csv(res_csv, index=False)
dup_df.to_csv(dup_csv, index=False)
if nd_df:
    nd_df.to_csv(nd_csv, index=False)
# Out:
# Extracting data from RESA2...
#     Done.
#
# Converting units and applying sea-salt correction...
#     Done.
#
# Calculating statistics...
#     Data series for Al at site 38089 has fewer than 10 non-null values. Significance estimates may be unreliable.
#     Data series for Al at site 38090 has fewer than 10 non-null values. Significance estimates may be unreliable.
#     Data series for Al at site 38091 has fewer than 10 non-null values. Significance estimates may be unreliable.
#     Data series for Al at site 38093 has fewer than 10 non-null values. Significance estimates may be unreliable.
#     Data series for TOC at site 38101 has fewer than 10 non-null values. Significance estimates may be unreliable.
#     Data series for EH at site 38101 has fewer than 10 non-null values. Significance estimates may be unreliable.
#     Data series for ESO4 at site 38101 has fewer than 10 non-null values. Significance estimates may be unreliable.
#     Data series for ECl at site 38101 has fewer than 10 non-null values. Significance estimates may be unreliable.
#     Data series for ENO3 at site 38101 has fewer than 10 non-null values. Significance estimates may be unreliable.
#     Data series for ESO4X at site 38101 has fewer than 10 non-null values. Significance estimates may be unreliable.
#     Data series for ESO4_ECl at site 38101 has fewer than 10 non-null values. Significance estimates may be unreliable.
#     Data series for ECa_EMg at site 38101 has fewer than 10 non-null values. Significance estimates may be unreliable.
#     Data series for ECaX_EMgX at site 38101 has fewer than 10 non-null values. Significance estimates may be unreliable.
#     Data series for ANC at site 38101 has fewer than 10 non-null values. Significance estimates may be unreliable.
#     Data series for Al at site 38211 has fewer than 10 non-null values. Significance estimates may be unreliable.
#     Data series for Al at site 38236 has fewer than 10 non-null values. Significance estimates may be unreliable.
#     Data series for Al at site 38237 has fewer than 10 non-null values. Significance estimates may be unreliable.
#     Data series for Al at site 38238 has fewer than 10 non-null values. Significance estimates may be unreliable.
#     Data series for Al at site 38239 has fewer than 10 non-null values. Significance estimates may be unreliable.
#     Data series for Al at site 38250 has fewer than 10 non-null values. Significance estimates may be unreliable.
#     Data series for Al at site 38258 has fewer than 10 non-null values. Significance estimates may be unreliable.
#     Data series for Al at site 38272 has fewer than 10 non-null values. Significance estimates may be unreliable.
#     Data series for Al at site 38280 has fewer than 10 non-null values. Significance estimates may be unreliable.
#     Data series for Al at site 38291 has fewer than 10 non-null values. Significance estimates may be unreliable.
#     Data series for Al at site 38301 has fewer than 10 non-null values. Significance estimates may be unreliable.
#     Data series for Al at site 38307 has fewer than 10 non-null values. Significance estimates may be unreliable.
#     Data series for EH at site 38494 has fewer than 10 non-null values. Significance estimates may be unreliable.
#     Data series for EH at site 38495 has fewer than 10 non-null values. Significance estimates may be unreliable.
#     Data series for EH at site 38496 has fewer than 10 non-null values. Significance estimates may be unreliable.
#     Data series for EH at site 38497 has fewer than 10 non-null values. Significance estimates may be unreliable.
#     Data series for EH at site 38498 has fewer than 10 non-null values. Significance estimates may be unreliable.
#     Data series for EH at site 38499 has fewer than 10 non-null values. Significance estimates may be unreliable.
#     Data series for EH at site 38500 has fewer than 10 non-null values. Significance estimates may be unreliable.
#     Data series for EH at site 38501 has fewer than 10 non-null values. Significance estimates may be unreliable.
#     Done.
#
# Finished.

# %% [markdown]
# ## 3. 1998 to 2016

# %%
# Specify period of interest
st_yr, end_yr = 1998, 2016

# Build output paths
plot_fold = os.path.join(res_fold, 'trends_plots_%s-%s' % (st_yr, end_yr))
res_csv = os.path.join(res_fold, 'res_%s-%s.csv' % (st_yr, end_yr))
dup_csv = os.path.join(res_fold, 'dup_%s-%s.csv' % (st_yr, end_yr))
nd_csv = os.path.join(res_fold, 'nd_%s-%s.csv' % (st_yr, end_yr))

# Run analysis 
res_df, dup_df, nd_df = resa2_trends.run_trend_analysis(proj_list, 
                                                        eng,
                                                        st_yr=st_yr, 
                                                        end_yr=end_yr,
                                                        plot=False, 
                                                        fold=None)

# Delete mk_std_dev col as not relevant here
del res_df['mk_std_dev']

# Write output
res_df.to_csv(res_csv, index=False)
dup_df.to_csv(dup_csv, index=False)
if nd_df:
    nd_df.to_csv(nd_csv, index=False)
# Out:
# Extracting data from RESA2...
#     Done.
#
# Converting units and applying sea-salt correction...
#     Done.
#
# Calculating statistics...
#     Data series for Al at site 38089 has fewer than 10 non-null values. Significance estimates may be unreliable.
#     Data series for Al at site 38090 has fewer than 10 non-null values. Significance estimates may be unreliable.
#     Data series for Al at site 38091 has fewer than 10 non-null values. Significance estimates may be unreliable.
#     Data series for Al at site 38092 has fewer than 10 non-null values. Significance estimates may be unreliable.
#     Data series for Al at site 38093 has fewer than 10 non-null values. Significance estimates may be unreliable.
#     Data series for TOC at site 38101 has fewer than 10 non-null values. Significance estimates may be unreliable.
#     Data series for EH at site 38101 has fewer than 10 non-null values. Significance estimates may be unreliable.
#     Data series for ESO4 at site 38101 has fewer than 10 non-null values. Significance estimates may be unreliable.
#     Data series for ECl at site 38101 has fewer than 10 non-null values. Significance estimates may be unreliable.
#     Data series for ENO3 at site 38101 has fewer than 10 non-null values. Significance estimates may be unreliable.
#     Data series for ESO4X at site 38101 has fewer than 10 non-null values. Significance estimates may be unreliable.
#     Data series for ESO4_ECl at site 38101 has fewer than 10 non-null values. Significance estimates may be unreliable.
#     Data series for Al at site 38210 has fewer than 10 non-null values. Significance estimates may be unreliable.
#     Data series for Al at site 38211 has fewer than 10 non-null values. Significance estimates may be unreliable.
#     Data series for Al at site 38218 has fewer than 10 non-null values. Significance estimates may be unreliable.
#     Data series for Al at site 38221 has fewer than 10 non-null values. Significance estimates may be unreliable.
#     Data series for Al at site 38234 has fewer than 10 non-null values. Significance estimates may be unreliable.
#     Data series for Al at site 38236 has fewer than 10 non-null values. Significance estimates may be unreliable.
#     Data series for Al at site 38237 has fewer than 10 non-null values. Significance estimates may be unreliable.
#     Data series for Al at site 38238 has fewer than 10 non-null values. Significance estimates may be unreliable.
#     Data series for Al at site 38239 has fewer than 10 non-null values. Significance estimates may be unreliable.
#     Data series for Al at site 38250 has fewer than 10 non-null values. Significance estimates may be unreliable.
#     Data series for Al at site 38258 has fewer than 10 non-null values. Significance estimates may be unreliable.
#     Data series for Al at site 38272 has fewer than 10 non-null values. Significance estimates may be unreliable.
#     Data series for Al at site 38280 has fewer than 10 non-null values. Significance estimates may be unreliable.
#     Data series for Al at site 38291 has fewer than 10 non-null values. Significance estimates may be unreliable.
#     Data series for Al at site 38301 has fewer than 10 non-null values. Significance estimates may be unreliable.
#     Data series for Al at site 38307 has fewer than 10 non-null values. Significance estimates may be unreliable.
#     Data series for EH at site 38494 has fewer than 10 non-null values. Significance estimates may be unreliable.
#     Data series for EH at site 38495 has fewer than 10 non-null values. Significance estimates may be unreliable.
#     Data series for EH at site 38496 has fewer than 10 non-null values. Significance estimates may be unreliable.
#     Data series for EH at site 38497 has fewer than 10 non-null values. Significance estimates may be unreliable.
#     Data series for EH at site 38498 has fewer than 10 non-null values. Significance estimates may be unreliable.
#     Data series for EH at site 38499 has fewer than 10 non-null values. Significance estimates may be unreliable.
#     Data series for EH at site 38500 has fewer than 10 non-null values. Significance estimates may be unreliable.
#     Data series for EH at site 38501 has fewer than 10 non-null values. Significance estimates may be unreliable.
#     Done.
#
# Finished.

# %% [markdown]
# ## 4. 1990 to 2008

# %%
# Specify period of interest
st_yr, end_yr = 1990, 2008

# Build output paths
plot_fold = os.path.join(res_fold, 'trends_plots_%s-%s' % (st_yr, end_yr))
res_csv = os.path.join(res_fold, 'res_%s-%s.csv' % (st_yr, end_yr))
dup_csv = os.path.join(res_fold, 'dup_%s-%s.csv' % (st_yr, end_yr))
nd_csv = os.path.join(res_fold, 'nd_%s-%s.csv' % (st_yr, end_yr))

# Run analysis 
res_df, dup_df, nd_df = resa2_trends.run_trend_analysis(proj_list, 
                                                        eng,
                                                        st_yr=st_yr, 
                                                        end_yr=end_yr,
                                                        plot=False, 
                                                        fold=None)

# Delete mk_std_dev col as not relevant here
del res_df['mk_std_dev']

# Write output
res_df.to_csv(res_csv, index=False)
dup_df.to_csv(dup_csv, index=False)
if nd_df:
    nd_df.to_csv(nd_csv, index=False)
# Out:
# Extracting data from RESA2...
#     Done.
#
# Converting units and applying sea-salt correction...
#     Done.
#
# Calculating statistics...
#     Data series for Al at site 38089 has fewer than 10 non-null values. Significance estimates may be unreliable.
#     Data series for Al at site 38090 has fewer than 10 non-null values. Significance estimates may be unreliable.
#     Data series for Al at site 38091 has fewer than 10 non-null values. Significance estimates may be unreliable.
#     Data series for Al at site 38092 has fewer than 10 non-null values. Significance estimates may be unreliable.
#     Data series for Al at site 38093 has fewer than 10 non-null values. Significance estimates may be unreliable.
#     Data series for TOC at site 38101 has fewer than 10 non-null values. Significance estimates may be unreliable.
#     Data series for EH at site 38101 has fewer than 10 non-null values. Significance estimates may be unreliable.
#     Data series for ESO4 at site 38101 has fewer than 10 non-null values. Significance estimates may be unreliable.
#     Data series for ECl at site 38101 has fewer than 10 non-null values. Significance estimates may be unreliable.
#     Data series for ENO3 at site 38101 has fewer than 10 non-null values. Significance estimates may be unreliable.
#     Data series for ESO4X at site 38101 has fewer than 10 non-null values. Significance estimates may be unreliable.
#     Data series for ESO4_ECl at site 38101 has fewer than 10 non-null values. Significance estimates may be unreliable.
#     Data series for ECa_EMg at site 38101 has fewer than 10 non-null values. Significance estimates may be unreliable.
#     Data series for ECaX_EMgX at site 38101 has fewer than 10 non-null values. Significance estimates may be unreliable.
#     Data series for ANC at site 38101 has fewer than 10 non-null values. Significance estimates may be unreliable.
#     Data series for TOC at site 38208 has fewer than 10 non-null values. Significance estimates may be unreliable.
#     Data series for Al at site 38210 has fewer than 10 non-null values. Significance estimates may be unreliable.
#     Data series for Al at site 38211 has fewer than 10 non-null values. Significance estimates may be unreliable.
#     Data series for Al at site 38212 has fewer than 10 non-null values. Significance estimates may be unreliable.
#     Data series for Al at site 38216 has fewer than 10 non-null values. Significance estimates may be unreliable.
#     Data series for Al at site 38221 has fewer than 10 non-null values. Significance estimates may be unreliable.
#     Data series for Al at site 38234 has fewer than 10 non-null values. Significance estimates may be unreliable.
#     Data series for Al at site 38238 has fewer than 10 non-null values. Significance estimates may be unreliable.
#     Data series for Al at site 38250 has fewer than 10 non-null values. Significance estimates may be unreliable.
#     Data series for Al at site 38258 has fewer than 10 non-null values. Significance estimates may be unreliable.
#     Data series for Al at site 38272 has fewer than 10 non-null values. Significance estimates may be unreliable.
#     Data series for Al at site 38280 has fewer than 10 non-null values. Significance estimates may be unreliable.
#     Data series for Al at site 38291 has fewer than 10 non-null values. Significance estimates may be unreliable.
#     Data series for Al at site 38301 has fewer than 10 non-null values. Significance estimates may be unreliable.
#     Data series for Al at site 38307 has fewer than 10 non-null values. Significance estimates may be unreliable.
#     Data series for TOC at site 38432 has fewer than 10 non-null values. Significance estimates may be unreliable.
#     Data series for EH at site 38432 has fewer than 10 non-null values. Significance estimates may be unreliable.
#     Data series for ESO4 at site 38432 has fewer than 10 non-null values. Significance estimates may be unreliable.
#     Data series for ECl at site 38432 has fewer than 10 non-null values. Significance estimates may be unreliable.
#     Data series for ENO3 at site 38432 has fewer than 10 non-null values. Significance estimates may be unreliable.
#     Data series for ESO4X at site 38432 has fewer than 10 non-null values. Significance estimates may be unreliable.
#     Data series for ESO4_ECl at site 38432 has fewer than 10 non-null values. Significance estimates may be unreliable.
#     Data series for ECa_EMg at site 38432 has fewer than 10 non-null values. Significance estimates may be unreliable.
#     Data series for ECaX_EMgX at site 38432 has fewer than 10 non-null values. Significance estimates may be unreliable.
#     Data series for ANC at site 38432 has fewer than 10 non-null values. Significance estimates may be unreliable.
#     Done.
#
# Finished.

# %% [markdown]
# ## 5. All data

# %%
# Specify period of interest
st_yr, end_yr = None, None

# Build output paths
plot_fold = os.path.join(res_fold, 'trends_plots_all_years')
res_csv = os.path.join(res_fold, 'res_all_years.csv')
dup_csv = os.path.join(res_fold, 'dup_all_years.csv')
nd_csv = os.path.join(res_fold, 'nd_all_years.csv')

# Run analysis 
res_df, dup_df, nd_df = resa2_trends.run_trend_analysis(proj_list, 
                                                        eng,
                                                        st_yr=st_yr, 
                                                        end_yr=end_yr,
                                                        plot=False, 
                                                        fold=None)

# Delete mk_std_dev col as not relevant here
del res_df['mk_std_dev']

# Write output
res_df.to_csv(res_csv, index=False)
dup_df.to_csv(dup_csv, index=False)
if nd_df:
    nd_df.to_csv(nd_csv, index=False)
# Out:
# Extracting data from RESA2...
#     Done.
#
# Converting units and applying sea-salt correction...
#     Done.
#
# Calculating statistics...
#     Data series for TOC at site 38101 has fewer than 10 non-null values. Significance estimates may be unreliable.
#     Data series for EH at site 38101 has fewer than 10 non-null values. Significance estimates may be unreliable.
#     Data series for ESO4 at site 38101 has fewer than 10 non-null values. Significance estimates may be unreliable.
#     Data series for ECl at site 38101 has fewer than 10 non-null values. Significance estimates may be unreliable.
#     Data series for ENO3 at site 38101 has fewer than 10 non-null values. Significance estimates may be unreliable.
#     Data series for ESO4X at site 38101 has fewer than 10 non-null values. Significance estimates may be unreliable.
#     Data series for ESO4_ECl at site 38101 has fewer than 10 non-null values. Significance estimates may be unreliable.
#     Data series for ECa_EMg at site 38101 has fewer than 10 non-null values. Significance estimates may be unreliable.
#     Data series for ECaX_EMgX at site 38101 has fewer than 10 non-null values. Significance estimates may be unreliable.
#     Data series for ANC at site 38101 has fewer than 10 non-null values. Significance estimates may be unreliable.
#     Data series for Al at site 38211 has fewer than 10 non-null values. Significance estimates may be unreliable.
#     Data series for Al at site 38236 has fewer than 10 non-null values. Significance estimates may be unreliable.
#     Data series for Al at site 38237 has fewer than 10 non-null values. Significance estimates may be unreliable.
#     Data series for Al at site 38238 has fewer than 10 non-null values. Significance estimates may be unreliable.
#     Data series for Al at site 38239 has fewer than 10 non-null values. Significance estimates may be unreliable.
#     Data series for Al at site 38250 has fewer than 10 non-null values. Significance estimates may be unreliable.
#     Data series for Al at site 38258 has fewer than 10 non-null values. Significance estimates may be unreliable.
#     Data series for Al at site 38272 has fewer than 10 non-null values. Significance estimates may be unreliable.
#     Data series for Al at site 38280 has fewer than 10 non-null values. Significance estimates may be unreliable.
#     Data series for Al at site 38291 has fewer than 10 non-null values. Significance estimates may be unreliable.
#     Data series for Al at site 38301 has fewer than 10 non-null values. Significance estimates may be unreliable.
#     Data series for Al at site 38307 has fewer than 10 non-null values. Significance estimates may be unreliable.
#     Data series for EH at site 38494 has fewer than 10 non-null values. Significance estimates may be unreliable.
#     Data series for EH at site 38495 has fewer than 10 non-null values. Significance estimates may be unreliable.
#     Data series for EH at site 38496 has fewer than 10 non-null values. Significance estimates may be unreliable.
#     Data series for EH at site 38497 has fewer than 10 non-null values. Significance estimates may be unreliable.
#     Data series for EH at site 38498 has fewer than 10 non-null values. Significance estimates may be unreliable.
#     Data series for EH at site 38499 has fewer than 10 non-null values. Significance estimates may be unreliable.
#     Data series for EH at site 38500 has fewer than 10 non-null values. Significance estimates may be unreliable.
#     Data series for EH at site 38501 has fewer than 10 non-null values. Significance estimates may be unreliable.
#     Done.
#
# Finished.

# %% [markdown]
# ## 6. Basic checking
#
# ### 6.1. Boxplots
#
# The plot below can be compared to the previous results [here](https://nbviewer.jupyter.org/github/JamesSample/icpw/blob/master/toc_trends_oct_2016_part2.ipynb#6.1.-Boxplots). Overall, the two plots are very similar, which is reassuring.

# %%
# Set up plot
fig = plt.figure(figsize=(20,10))
sn.set(style="ticks", palette="muted", 
       color_codes=True, font_scale=2)

# Horizontal boxplots
ax = sn.boxplot(x="mean", y="par_id", data=res_df,
                whis=np.inf, color="c")

# Add "raw" data points for each observation, with some "jitter"
# to make them visible
sn.stripplot(x="mean", y="par_id", data=res_df, jitter=True, 
             size=3, color=".3", linewidth=0)

# Remove axis lines
sn.despine(trim=True)

# %% [markdown]
# ## 7. Data restructuring
#
# The code below is taken from [here](https://nbviewer.jupyter.org/github/JamesSample/icpw/blob/master/toc_trends_oct_2016_part2.ipynb#7.-Data-restructuring). It is used to generate output files in the format requested by Heleen.
#
# ### 7.1. Combine datasets

# %%
# Read results files and concatenate
# Container for data
df_list = []

# Loop over periods
for per in ['1990-2016', '1990-2008', '1998-2016', 'all_years']:
    res_path = os.path.join(res_fold, 'res_%s.csv' % per)
    df = pd.read_csv(res_path)
    
    # Change 'period' col to 'data_period' and add 'analysis_period'
    df['data_period'] = df['period']
    del df['period']
    
    df['analysis_period'] = per
    
    df_list.append(df)
    
# Concat
df = pd.concat(df_list, axis=0)

# Read station data
stn_path = r'../../update_autumn_2018/toc_trends_oct18_stations.xlsx'
stn_df = pd.read_excel(stn_path, sheet_name='Data', keep_default_na=False)

# Join
df = pd.merge(df, stn_df, how='left', on='station_id')

# Read projects table
sql = ("SELECT project_id, project_name "
       "FROM resa2.projects "
       "WHERE project_name = 'ICPW_TOCTRENDS_2018'")
proj_df = pd.read_sql_query(sql, eng)

# Get associated stations
sql = ("SELECT station_id, project_id "
       "FROM resa2.projects_stations "
       "WHERE project_id = 4390")
proj_stn_df = pd.read_sql_query(sql, eng)

# Join proj details
proj_df = pd.merge(proj_stn_df, proj_df, how='left', on ='project_id')

# Join to results
df = pd.merge(df, proj_df, how='left', on='station_id')

# Re-order columns
df = df[['project_id', 'project_name', 'station_id', 
         'station_code', 'station_name', 'nfc_code', 'type',
         'latitude', 'longitude', 'continent', 'country', 
         'region', 'subregion', 'analysis_period', 'data_period', 
         'par_id', 'non_missing', 'n_start', 'n_end', 'mean', 'median', 
         'std_dev', 'mk_stat', 'norm_mk_stat', 'mk_p_val', 'trend',
         'sen_slp']]

df.head()
# Out:
#    project_id         project_name  station_id station_code  \
# 0        4390  ICPW_TOCTRENDS_2018       38085    Tr18_CA01
# 1        4390  ICPW_TOCTRENDS_2018       38085    Tr18_CA01
# 2        4390  ICPW_TOCTRENDS_2018       38085    Tr18_CA01
# 3        4390  ICPW_TOCTRENDS_2018       38085    Tr18_CA01
# 4        4390  ICPW_TOCTRENDS_2018       38085    Tr18_CA01
#
#                               station_name nfc_code type  latitude  longitude  \
# 0  Ontario, Algoma Region, Batchawana Lake             L     47.06    -84.393
# 1  Ontario, Algoma Region, Batchawana Lake             L     47.06    -84.393
# 2  Ontario, Algoma Region, Batchawana Lake             L     47.06    -84.393
# 3  Ontario, Algoma Region, Batchawana Lake             L     47.06    -84.393
# 4  Ontario, Algoma Region, Batchawana Lake             L     47.06    -84.393
#
#   continent    ...    n_start n_end        mean      median    std_dev  \
# 0        NA    ...          5     5  102.129696  104.000000  19.108938
# 1        NA    ...          5     5    4.703870    4.668000   0.319514
# 2        NA    ...          5     5    1.049825    1.023293   0.251578
# 3        NA    ...          5     5   84.743245   95.000000  20.025680
# 4        NA    ...          5     5    7.166138    7.142857   1.951420
#
#   mk_stat  norm_mk_stat      mk_p_val       trend   sen_slp
# 0    19.0      0.375244  7.074787e-01    no trend  0.121250
# 1   142.0      2.940053  3.281559e-03  increasing  0.019687
# 2   -38.0     -0.772287  4.399443e-01    no trend -0.005823
# 3  -289.0     -6.003910  1.926214e-09  decreasing -2.333912
# 4  -135.0     -2.811464  4.931664e-03  decreasing -0.155429
#
# [5 rows x 27 columns]

# %% [markdown]
# ### 7.2. Check record completeness
#
# See e-mail from Heleen received 25/10/2016 at 15:56. The `'non_missing'` threshold is based of 65% of the data period (e.g. 65% of 27 years for 1990 to 2016).

# %%
def include(row):
    if ((row['analysis_period'] == '1990-2016') & 
        (row['n_start'] >= 2) &
        (row['n_end'] >= 2) &
        (row['non_missing'] >= 18)):
        return 'yes'
    elif ((row['analysis_period'] == '1990-2008') & 
          (row['n_start'] >= 2) &
          (row['n_end'] >= 2) &          
          (row['non_missing'] >= 12)):
        return 'yes'
    elif ((row['analysis_period'] == '1998-2016') & 
          (row['n_start'] >= 2) &
          (row['n_end'] >= 2) &          
          (row['non_missing'] >= 12)):
        return 'yes'
    else:
        return 'no'

df['include'] = df.apply(include, axis=1)

# %% [markdown]
# ### 7.3. SO4 at Abiskojaure
#
# SO4 for this station (`'station_id=38335'`) should be removed. See [here](https://nbviewer.jupyter.org/github/JamesSample/icpw/blob/master/toc_trends_oct_2016_part3.ipynb#1.3.-SO4-for-station-ID-36561).

# %%
# Remove sulphate-related series at Abiskojaure
df = df.query('not((station_id==38335) and ((par_id=="ESO4") or '
                                           '(par_id=="ESO4X") or '
                                           '(par_id=="ESO4_ECl")))')

# %% [markdown]
# ### 7.4. Relative slope

# %%
# Relative slope
df['rel_sen_slp'] = df['sen_slp'] / df['median']

# %% [markdown]
# ### 7.5. Tidy

# %%
# Remove unwanted cols
df.drop(labels=['mean', 'n_end', 'n_start', 'mk_stat', 'norm_mk_stat'],
        axis=1, inplace=True)

# Reorder columns
df = df[['project_id', 'project_name', 'station_id', 'station_code', 
         'station_name', 'nfc_code', 'type', 'continent', 'country', 
         'region', 'subregion', 'latitude', 'longitude', 'analysis_period',
         'data_period', 'par_id', 'non_missing', 'median', 'std_dev',
         'mk_p_val', 'trend', 'sen_slp', 'rel_sen_slp', 'include']]

# Write to output
out_path = r'../../update_autumn_2018/results/toc_trends_long_format.csv'
df.to_csv(out_path, index=False, encoding='utf-8')

df.head()
# Out:
#    project_id         project_name  station_id station_code  \
# 0        4390  ICPW_TOCTRENDS_2018       38085    Tr18_CA01
# 1        4390  ICPW_TOCTRENDS_2018       38085    Tr18_CA01
# 2        4390  ICPW_TOCTRENDS_2018       38085    Tr18_CA01
# 3        4390  ICPW_TOCTRENDS_2018       38085    Tr18_CA01
# 4        4390  ICPW_TOCTRENDS_2018       38085    Tr18_CA01
#
#                               station_name nfc_code type continent country  \
# 0  Ontario, Algoma Region, Batchawana Lake             L        NA  Canada
# 1  Ontario, Algoma Region, Batchawana Lake             L        NA  Canada
# 2  Ontario, Algoma Region, Batchawana Lake             L        NA  Canada
# 3  Ontario, Algoma Region, Batchawana Lake             L        NA  Canada
# 4  Ontario, Algoma Region, Batchawana Lake             L        NA  Canada
#
#   region   ...    data_period  par_id  non_missing      median    std_dev  \
# 0    ONT   ...      1990-2016      Al           27  104.000000  19.108938
# 1    ONT   ...      1990-2016     TOC           27    4.668000   0.319514
# 2    ONT   ...      1990-2016      EH           27    1.023293   0.251578
# 3    ONT   ...      1990-2016    ESO4           27   95.000000  20.025680
# 4    ONT   ...      1990-2016     ECl           27    7.142857   1.951420
#
#        mk_p_val       trend   sen_slp  rel_sen_slp  include
# 0  7.074787e-01    no trend  0.121250     0.001166      yes
# 1  3.281559e-03  increasing  0.019687     0.004218      yes
# 2  4.399443e-01    no trend -0.005823    -0.005691      yes
# 3  1.926214e-09  decreasing -2.333912    -0.024567      yes
# 4  4.931664e-03  decreasing -0.155429    -0.021760      yes
#
# [5 rows x 24 columns]

# %% [markdown]
# ### 7.6. Convert to "wide" format

# %%
del df['data_period']

# Melt to "long" format
melt_df = pd.melt(df, 
                  id_vars=['project_id', 'project_name', 'station_id', 'station_code', 
                           'station_name', 'nfc_code', 'type', 'continent', 'country', 
                           'region', 'subregion', 'latitude', 'longitude', 
                           'analysis_period', 'par_id', 'include'],
                  var_name='stat')

# Get only values where include='yes'
melt_df = melt_df.query('include == "yes"')
del melt_df['include']

# Build multi-index on everything except "value"
melt_df.set_index(['project_id', 'project_name', 'station_id', 'station_code', 
                   'station_name', 'nfc_code', 'type', 'continent', 'country', 
                   'region', 'subregion', 'latitude', 'longitude', 'par_id', 
                   'analysis_period', 
                   'stat'], inplace=True)

# Unstack levels of interest to columns
wide_df = melt_df.unstack(level=['par_id', 'analysis_period', 'stat'])

# Drop unwanted "value" level in index
wide_df.columns = wide_df.columns.droplevel(0)

# Replace multi-index with separate components concatenated with '_'
wide_df.columns = ["_".join(item) for item in wide_df.columns]

# Reset multiindex on rows
wide_df = wide_df.reset_index()

# Save output
out_path = os.path.join(res_fold, 'toc_trends_wide_format.csv')
wide_df.to_csv(out_path, index=False, encoding='utf-8')

wide_df.head()
# Out:
#    project_id         project_name  station_id station_code  \
# 0        4390  ICPW_TOCTRENDS_2018       38085    Tr18_CA01
# 1        4390  ICPW_TOCTRENDS_2018       38086    Tr18_CA02
# 2        4390  ICPW_TOCTRENDS_2018       38087    Tr18_CA03
# 3        4390  ICPW_TOCTRENDS_2018       38088    Tr18_CA04
# 4        4390  ICPW_TOCTRENDS_2018       38089    Tr18_CA05
#
#                                  station_name nfc_code type continent country  \
# 0     Ontario, Algoma Region, Batchawana Lake             L        NA  Canada
# 1        Ontario, Algoma Region, Wishart Lake             L        NA  Canada
# 2  Ontario, Algoma Region, Little Turkey Lake             L        NA  Canada
# 3         Ontario, Algoma Region, Turkey Lake             L        NA  Canada
# 4                        Quebec, Lac Veilleux             L        NA  Canada
#
#    region            ...            TOC_1998-2016_rel_sen_slp  \
# 0     ONT            ...                         -0.000206526
# 1     ONT            ...                          -0.00138045
# 2     ONT            ...                          -0.00219126
# 3     ONT            ...                          -0.00279375
# 4  QuMaVt            ...                            0.0138456
#
#    EH_1998-2016_rel_sen_slp  ESO4_1998-2016_rel_sen_slp  \
# 0                         0                  -0.0409693
# 1                         0                  -0.0278806
# 2                 0.0117683                  -0.0254878
# 3                0.00350297                  -0.0233615
# 4                -0.0193069                  -0.0350877
#
#   ECl_1998-2016_rel_sen_slp ENO3_1998-2016_rel_sen_slp  \
# 0                -0.0399351                -0.00918635
# 1                -0.0281506                -0.00118577
# 2                -0.0352381                 0.00357143
# 3                -0.0330796                       0.01
# 4                    -0.025                 -0.0572581
#
#   ESO4X_1998-2016_rel_sen_slp ESO4_ECl_1998-2016_rel_sen_slp  \
# 0                  -0.0408945                     -0.0419529
# 1                  -0.0275847                     -0.0286529
# 2                  -0.0253666                     -0.0266943
# 3                  -0.0231876                     -0.0246551
# 4                  -0.0336744                     -0.0283703
#
#   ECa_EMg_1998-2016_rel_sen_slp ECaX_EMgX_1998-2016_rel_sen_slp  \
# 0                   -0.00571467                     -0.00568085
# 1                   -0.00279341                     -0.00252812
# 2                   -0.00164716                     -0.00145702
# 3                    0.00169334                      0.00182297
# 4                   -0.00577778                     -0.00363245
#
#   ANC_1998-2016_rel_sen_slp
# 0                 0.0337988
# 1                 0.0184909
# 2                 0.0138315
# 3                 0.0135365
# 4                 0.0126897
#
# [5 rows x 244 columns]
